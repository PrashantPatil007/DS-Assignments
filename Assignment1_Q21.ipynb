# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats

# %%
cars=pd.read_csv("D:\DS Assignments\Datasets\Assign 1\Cars.csv")

# %%
df=cars.MPG

# %%
df.head()
# Out:
# 0    53.700681
# 1    50.013401
# 2    50.013401
# 3    45.696322
# 4    50.504232
# Name: MPG, dtype: float64

# %%
df.hist()
# Out:
# <Axes: >

# %%
import statsmodels.api as sm

# %%
sm.qqplot(df, line='s')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.title('Q-Q Plot of Data')
plt.show()

# %%
df2=pd.read_csv("D:\DS Assignments\Datasets\Assign 1\wc-at.csv")

# %%
df2.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
df2.Waist.hist()
# Out:
# <Axes: >

# %%
sm.qqplot(df2.Waist, line='s')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.title('Q-Q Plot of Data')
plt.show()

# %%
df2.AT.hist()
# Out:
# <Axes: >

# %%
sm.qqplot(df2.AT, line='s')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.title('Q-Q Plot of Data')
plt.show()
